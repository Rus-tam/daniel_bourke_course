# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Introduction to neural network classification with TensorFlow
#
# In this notebook we are going to learn how to write neural networks for classification problems
#
# A classification is where you try to classify something as one thing or another
# A few types of classification problems:
#
# * Binary classification
# * Multiclass classification
# * Multilabel classification

# %% [markdown]
# ## Creating data to view and fit

# %%
from sklearn.datasets import make_circles

# Make 1000 examples
n_samples = 10000

# Create circles
X, y = make_circles(n_samples,
                   noise=0.03,
                   random_state=42)

# Data visualization
plt.figure(figsize=(8, 6))
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], color='red', label='Class 0')
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], color='blue', label='Class 1')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Visualization of make_circles dataset')
plt.legend()
plt.show()

# %%
# Check the features
X
# Out:
# array([[ 0.0464692 ,  0.82477834],
#        [ 1.00506323, -0.43335153],
#        [-0.58348442,  0.79452834],
#        ...,
#        [ 0.6854581 ,  0.37297955],
#        [ 0.47440334,  0.88491997],
#        [-0.67440999,  0.26094865]])

# %%
# Check the labels
y[:10]
# Out:
# array([1, 0, 0, 0, 0, 1, 0, 1, 1, 0], dtype=int64)

# %% [markdown]
# # Our data is a little hard to understand right now.. let's visualize it!

# %%
circles = pd.DataFrame({"X0": X[:, 0], "X1": X[:, 1], "label":y})
circles
# Out:
#             X0        X1  label
# 0     0.046469  0.824778      1
# 1     1.005063 -0.433352      0
# 2    -0.583484  0.794528      0
# 3     0.984783 -0.325179      0
# 4     0.829930 -0.547223      0
# ...        ...       ...    ...
# 9995  0.505764  0.662722      1
# 9996  0.790650  0.218306      1
# 9997  0.685458  0.372980      1
# 9998  0.474403  0.884920      0
# 9999 -0.674410  0.260949      1
#
# [10000 rows x 3 columns]

# %%
# Visualize with a plot
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlBu);

# %% [markdown]
# ## Input and output shapes

# %%
# Check the shapes of our features and labels
X.shape, y.shape
# Out:
# ((10000, 2), (10000,))

# %%
# View the first example of features and labels
X[0], y[0]
# Out:
# (array([0.0464692 , 0.82477834]), 1)

# %% [markdown]
# ## Steps in modeling
#
# The steps in modelling with TensorFlow are typically:
#
# 1. Create or import a model
# 2. Compile the model
# 3. Fit the model
# 4. Evaluate the model
# 5. Tweak
# 6. Evaluate...

# %%
# Check tf version
tf.__version__
# Out:
# '2.12.0-rc1'

# %%
# Set the random seed
tf.random.set_seed(42)

# 1. Create the model using the Sequantial API
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# 2. Compile the model
model_1.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["accuracy"])

# 3. Fit the model
model_1.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 1s 991us/step - loss: 1.5449 - accuracy: 0.4853
# Epoch 2/5
# 313/313 [==============================] - 0s 743us/step - loss: 0.6938 - accuracy: 0.4959
# Epoch 3/5
# 313/313 [==============================] - 0s 869us/step - loss: 0.6939 - accuracy: 0.4960
# Epoch 4/5
# 313/313 [==============================] - 0s 956us/step - loss: 0.6938 - accuracy: 0.5015
# Epoch 5/5
# 313/313 [==============================] - 0s 887us/step - loss: 0.6938 - accuracy: 0.4997

# %%
# Let's try and improve our model by training for longer ...
model_1.fit(X, y, epochs=200, verbose=0)

# %%
model_1.evaluate(X, y)
# Out:
# 313/313 [==============================] - 0s 842us/step - loss: 0.6937 - accuracy: 0.5004
# [0.6936948299407959, 0.5004000067710876]

# %% [markdown]
# Since we're working on a binary classification problem and our model is getiing around 50% accuracy... it's performing as if it's guessing.
#
# So let's step things up a notch and add an extra layer.

# %%
# Set the random seed
tf.random.set_seed(42)

# 1. Create the model using the Sequantial API
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(1),
    tf.keras.layers.Dense(1)
])

# 2. Compile the model
model_2.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["accuracy"])

# 3. Fit the model
model_2.fit(X, y, epochs=100, verbose=0)

# %%
# 4. Evaluate the model
model_2.evaluate(X, y)
# Out:
# 313/313 [==============================] - 0s 760us/step - loss: 0.6933 - accuracy: 0.5000
# [0.6932668089866638, 0.5]

# %% [markdown]
# ## Improving our model
